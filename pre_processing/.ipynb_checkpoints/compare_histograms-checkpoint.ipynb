# %%
from preprocessing import PreProcessing
import pydicom
import matplotlib.pyplot as plt

# %%
path_image_1 = "/home/gpds/Documentos/imagens-médicas/projeto_cecilia/avc-pacientes-renomeados/151-200/Paciente152 (5).dcm"
path_image_2 = "/home/gpds/Documentos/CT-500Info/CT_500_choosen_files/0/Treino/302/CT000100.dcm"

# %%
ds_tc = pydicom.dcmread(path_image_1)
ds_tc2 = pydicom.dcmread(path_image_2)

# %%
plt.hist(ds_tc.pixel_array.ravel())
# Out:
# (array([57302., 87996.,  6126.,  5046., 74629., 11508.,  7499.,  5671.,
#          4709.,  1658.]),
#  array([-1500. , -1182.7,  -865.4,  -548.1,  -230.8,    86.5,   403.8,
#           721.1,  1038.4,  1355.7,  1673. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ds_tc2.pixel_array.ravel())
# Out:
# /home/gpds/.local/lib/python3.8/site-packages/pydicom/pixel_data_handlers/pillow_handler.py:238: UserWarning: The (0028,0101) 'Bits Stored' value (16-bit) doesn't match the JPEG 2000 data (14-bit). It's recommended that you change the 'Bits Stored' value
#   warnings.warn(
# (array([ 55772.,      0.,      0.,      0., 105656.,   4269.,  77993.,
#           6705.,   5354.,   6395.]),
#  array([-2000. , -1530.9, -1061.8,  -592.7,  -123.6,   345.5,   814.6,
#          1283.7,  1752.8,  2221.9,  2691. ]),
#  <BarContainer object of 10 artists>)

# %%
preprocessing = PreProcessing()
img = preprocessing.make_jan(ds_tc.pixel_array, [0,100])
plt.imshow(img, cmap="gray")

# %%
img = preprocessing.make_jan(ds_tc2.pixel_array, [-900,1022])
plt.imshow(img, cmap="gray")
